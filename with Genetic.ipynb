# %%
import pandas as pd


data = pd.read_csv("indoc.csv")
data.head(10)
# Out:
#    Unnamed: 0  Unnamed: 0.1  \
# 0           0             0
# 1           1             1
# 2           3             3
# 3           4             4
# 4           6             6
# 5           7             7
# 6           8             8
# 7          12            12
# 8          13            13
# 9          17            17
#
#                                             Document         class  \
# 0  স্নাতক পাস আবুল হাশেম (৩০) ও তাঁর ভাই উচ্চমাধ্...  ['বাংলাদেশ']
# 1  ঢাকার কামরাঙ্গীরচরের নবাবচরে বুড়িগঙ্গা নদী দখল...  ['বাংলাদেশ']
# 2  হবিগঞ্জের শায়েস্তাগঞ্জের বিউটি আক্তার হত্যার প...  ['বাংলাদেশ']
# 3    কিশোরগঞ্জ সদরে একই স্থানে আওয়ামী লীগ ও ছাত্র...  ['বাংলাদেশ']
# 4  নির্বাচন সামনে রেখে ঢাকা-১৩ সংসদীয় এলাকায় প্রধ...  ['বাংলাদেশ']
# 5  কর্মরত নারী গার্মেন্টস শ্রমিকদের আবাসনের জন্য ...  ['বাংলাদেশ']
# 6  খুলনা ও গাজীপুর সিটি করপোরেশন নির্বাচনে অংশ নে...  ['বাংলাদেশ']
# 7  প্রধানমন্ত্রী শেখ হাসিনাকে কটূক্তি করায় খুলনা ...  ['বাংলাদেশ']
# 8  কারাবন্দী বিএনপির চেয়ারপারসন খালেদা জিয়ার স্বা...  ['বাংলাদেশ']
# 9  চুয়াডাঙ্গা শহরের ইম্প্যাক্ট মাসুদুল হক মেমোরিয়...  ['বাংলাদেশ']
#
#                                                 link
# 0  https://www.prothomalo.com/bangladesh/article/...
# 1  https://www.prothomalo.com/bangladesh/article/...
# 2  https://www.prothomalo.com/bangladesh/article/...
# 3  https://www.prothomalo.com/bangladesh/article/...
# 4  https://www.prothomalo.com/bangladesh/article/...
# 5  https://www.prothomalo.com/bangladesh/article/...
# 6  https://www.prothomalo.com/bangladesh/article/...
# 7  https://www.prothomalo.com/bangladesh/article/...
# 8  https://www.prothomalo.com/bangladesh/article/...
# 9  https://www.prothomalo.com/bangladesh/article/...

# %%
docs = data["Document"]

# %%
cl = [xs.replace('ইহাতে মন্তব্য প্রদান বন্ধ রয়েছে                                |    ', '') for xs in docs]
cl2 = [xs.replace('\xa0', '').replace('\u200c', '') for xs in cl]
cl3 = [xs.replace('?', u'।').replace('!', u'।').replace(';', u'।') for xs in cl]

sentTok =[]
wordTok = []
for doc in cl3:
    sentTok.append(doc.split('।'))
sentTok[0]
# Out:
# ['স্নাতক পাস আবুল হাশেম (৩০) ও তাঁর ভাই উচ্চমাধ্যমিক পাস সুজন হোসেন (২৩) একসময় ঢাকায় গার্মেন্টসে চাকরি করতেন',
#  ' তাঁদের আরেক ভাই অষ্টম শ্রেণি পাস ফরহাদ হোসেন (২৫) আগে নোয়াখালীতে গ্রামের বাড়িতে কৃষিকাজ করতেন',
#  ' এখন তিন ভাইই পরিবার নিয়ে ঢাকার উত্তরার বহুতল ভবনে বাস করেন',
#  ' ভাড়া দেন ৫০ হাজার টাকা',
#  ' গত শনিবার তিন ভাইয়ের দুজন সুজন ও ফরহাদকে ২০ হাজার পিছ ইয়াবাসহ উত্তরার সেই ফ্ল্যাট থেকে গ্রেপ্তার করেছে ঢাকা মহানগর গোয়েন্দা পুলিশ (ডিবি)',
#  ' এই ইয়াবার আনুমানিক মূল্য ৩০ লাখ টাকা',
#  ' আর তিন ভাইয়ের ফ্ল্যাট থেকে জব্দ করা হয়েছে আরও নগদ ২ লাখ ৫৭ হাজার টাকা',
#  ' রোববার সুজন ও ফরহাদকে ঢাকার আদালতে হাজির করে ডিবি এক প্রতিবেদন দিয়ে বলছে, হাশেম, সুজন ও ফরহাদ তিন ভাই কয়েক বছর ধরে কক্সবাজার থেকে ইয়াবার চালান ঢাকায় এনে জমজমাট ব্যবসা করছেন',
#  ' তাঁদের সঙ্গে কারা জড়িত, তা খুঁজে বের করতে দুই ভাইকে তিন দিন জিজ্ঞাসাবাদের অনুমতি দিয়েছেন আদালত',
#  ' তিনজনের বাবা ছিলেন হকারমাদক ব্যবসার অভিযোগ থাকা এই তিনজনের বাবার নাম বিল্লাল হোসেন',
#  ' তাঁর গ্রামের বাড়ি নোয়াখালী',
#  ' অনেক আগে থেকে তিনি ঢাকায় থাকেন',
#  ' রাজধানীর বিমানবন্দর এলাকায় ফুটপাতে হকারি করতেন',
#  ' পরিবার নিয়ে থাকতেন আশকোনাতে',
#  ' বিল্লাল হোসেন এখন এই তিন ছেলের সঙ্গে উত্তরার ছেলেদের ফ্ল্যাটে থাকেন',
#  ' ২০ হাজার পিছ ইয়াবাসহ যখন তাঁর দুই ছেলেকে গ্রেপ্তার করা হয়, তখন বিল্লাল হোসেন ওই বাসাতেই ছিলেন',
#  ' দুই ভাইকে গ্রেপ্তার অভিযানে অংশ নেওয়া ঢাকা মহানগর গোয়েন্দা পুলিশের সহকারী কমিশনার (এসি) মো মাহবুবুল আলম প্রথম আলোকে বলেন, বিল্লাল হোসেনের ছেলে সুজন এর আগেও মাদকসহ গ্রেপ্তার হয়েছিল',
#  ' এই তিন ভাই বেশ কয়েক বছর ধরে মাদক ব্যবসা করে আসছেন',
#  ' তিন ভাইয়ের বাসায় ইয়াবা ব্যবসাপুলিশ বলছে, এই তিন ভাইয়ের মধ্যে নেতা হলেন আবুল হাশেম',
#  ' কক্সবাজারের বড় বড় মাদক ব্যবসায়ীর সঙ্গে যোগাযোগ রেখে ইয়াবার চালান আনেন ঢাকায়',
#  ' এ কাজে তাঁরা নোয়াখালীকে ট্রানজিট হিসেবে ব্যবহার করেন',
#  ' আর তাঁর ভাই সুজন ও ফরহাদ ঢাকার পাইকারি ও খুচরা ব্যবসায়ীদের কাছে ইয়াবা বিক্রি করেন',
#  ' মামলার তদন্ত কর্মকর্তা ডিবির পরিদর্শক মুক্তার হোসেন প্রথম আলোকে বলেন, উত্তরার ওই ফ্ল্যাটে মাদক রাখতেন তিন ভাই',
#  ' তাঁদের ফ্ল্যাটে মাদক ব্যবসায়ীদের আনাগোনা ছিল',
#  ' গ্রেপ্তার অভিযানে অংশ নেওয়া একাধিক ডিবি কর্মকর্তা জানান, শনিবার নোয়াখালী থেকে ইয়াবার চালান বাসে করে আনেন সুজন ও ফরহাদ',
#  ' তবে তাঁদের ভাই আবুল হাশেম নোয়াখালীতেই থেকে যান',
#  ' ভাইদের গ্রেপ্তার হওয়ার খবর শোনার পর হাশেম গা–ঢাকা দিয়েছেন',
#  ' ডিবির সহকারী কমিশনার মাহবুবুল আলম প্রথম আলোকে বলেন, ভাইদের গ্রেপ্তার খবর শোনার পর থেকে হাশেমের মোবাইল ফোন বন্ধ পাওয়া যাচ্ছে',
#  ' তবে হাশেমকে যেকোনো সময় গ্রেপ্তার করা হবে',
#  ' মাহবুবুল আলম আরও বলেন, সুজন ও ফরহাদদের জিজ্ঞাসা করে জানতে পেরেছেন, মাদক ব্যবসা করে অনেক টাকা বানিয়েছেন',
#  ' এই ডিবি কর্মকর্তা মনে করছেন, হাশেমদের পুরো পরিবার মাদক ব্যবসার সঙ্গে জড়িত',
#  ' ']

# %%
import re
pnList = ['.', ',', ':', '(', ')', '[', ']', '{', '}', '`', '*', '&', '‘', '’', '–']
cl4 = [xs.replace(u'।'," ") for xs in cl3]

cl5=[[] for x in range(len(cl4))]
for i in range(len(cl4)):
#     cl5[i] = cl4[i].replace("(","").replace(")","").replace(",","").replace("+","").replace(")","")
    cl5[i] = re.sub("[০১২৩৪৫৬৭৮৯]",'',cl4[i])
    cl5[i] = re.sub("[,./<>)(}{_*&^%$#@~`]",'',cl5[i])

for doc in cl5:
    wordTok.append(doc.split())


#remove stopword
stRem = [[] for i in range(len(wordTok))]

def remStWords(punctuF):
    stWord = open("./stopwords-bn.txt", encoding='utf8')
    stWordFile = [i.rstrip() for i in stWord]
    filtStWord = [w for w in punctuF if w not in stWordFile]

    return filtStWord
for i in range(len(wordTok)):
    stRem[i] = remStWords(wordTok[i])
    

print(stRem[1])
# Out:
# ['ঢাকার', 'কামরাঙ্গীরচরের', 'নবাবচরে', 'বুড়িগঙ্গা', 'নদী', 'দখল', 'স্থায়ী', 'রূপ', 'নিচ্ছে', 'নদীর', 'সীমানা', 'নির্ধারণ', 'বিষয়ে', 'জেলা', 'প্রশাসনের', 'প্রতিবেদনের', 'কারণে', 'অবস্থার', 'সৃষ্টি', 'রয়েছে', 'প্রভাবশালী', 'ব্যক্তিদের', 'চাপ', 'অভ্যন্তরীণ', 'নৌপরিবহন', 'কর্তৃপক্ষের', 'বিআইডব্লিউটিএ', 'উদ্যোগের', 'অভাব', 'বিআইডব্লিউটিএ', 'জেলা', 'প্রশাসন', 'সূত্রে', 'নৌপরিবহনমন্ত্রী', 'শাজাহান', 'খান', 'গত', 'বছরের', 'এপ্রিলে', 'বুড়িগঙ্গার', 'কামরাঙ্গীরচর', 'এলাকা', 'পরিদর্শন', 'সময়', 'নদীর', 'জায়গায়', 'অবৈধ', 'স্থাপনা', 'গড়ে', 'উঠেছে', 'সেগুলো', 'ভাঙার', 'ঘোষণা', 'এরপর', 'জুলাই', 'বিআইডব্লিউটিএ', 'অভিযান', 'চালিয়ে', 'তিনটি', 'স্থাপনার', 'বাইরের', 'দেয়ালের', 'সামান্য', 'অংশ
া', 'নির্ধারণ', 'হয়েছে', 'অভিযোগের', 'ভিত্তিতেই', 'নৌমন্ত্রীর', 'আলোচনা', 'করেছিলাম', 'ভাঙতে', 'চায়', 'ভেঙে', 'দিক', '’', 'স্থাপনা', 'মেরামত', 'বাড়ানোর', 'উৎসব', 'নবাবচর', 'এলাকাটি', 'বুড়িগঙ্গা', 'নদীর', 'ঢাকা', 'প্রান্তে', 'গত', 'বৃহস্পতিবার', 'সকালে', 'এখানকার', 'গুদারাঘাট-আশ্রাফাবাদ', 'এলাকায়', 'যায়', 'নদীতীরে', 'অনেকগুলো', 'পাকা', 'ভবন', 'ভবন', 'তৈরির', 'প্রচুর', 'ইট', 'বালু', 'রড', 'সিমেন্ট', 'জড়ো', 'হয়েছে', 'তৈরি', 'বাড়িগুলোর', 'কোনোটায়', 'সদ্য', 'রং', 'লাগানো', 'হয়েছে', '‘ভাড়া', 'হবে’', 'সাইনবোর্ডও', 'ঝুলছে', 'এগুলোর', 'নদীর', 'সম্পূর্ণ', 'আংশিক', 'জায়গায়', 'অবস্থিত', 'এলাকাবাসী', 'জানান', 'গত', 'জুলাইয়ে', 'উচ্ছেদ', 'অভিযান', 'চালানোর', 'বেশির', 'ভাগ', 'বাড়ির', 'লোকজন', 'সরে', 'গিয়েছিলেন', 'মাসখানেক', 'সবাই', 'এসেছেন', 'ভেঙে', 'স্থাপনা', 'মেরামত', 'আগের', 'স্থাপনার', 'অংশও', 'যুক্ত', 'এলাকা', 'ঘুরে', 'যায়', 'নদীর', 'অস্থায়ী', 'সীমানা', 'খুঁটির', 'ভেতরের', 'জায়গায়', 'স্থাপনা', 'রয়েছে', 'ঢাকা-', 'আসনের', 'সাংসদ', 'হাজি', 'মো', 'সেলিমের', 'মালিকানাধীন', 'মদীনা', 'ট্রেডিংয়ের', 'রড-সিমেন্ট', 'বিক্রির', 'একতলা', 'পাকা', 'স্থাপনা', 'স', 'মিল', 'পাশের', 'দোতলা', 'ভবনের', 'মালিক', 'মো', 'সিরাজ', 'অংশ', 'যুক্ত', 'মো', 'সিরাজ', 'আলোকে', 'নদীর', 'এক', 'ইঞ্চি', 'জায়গাও', 'নেননি', 'গুদারাঘাট', 'সড়কের', 'পাশেই', 'ছয়তলা', 'ভবন', 'নির্মাণ', 'হয়েছে', 'উচ্ছেদ', 'অভিযানের', 'ভবনটি', 'তালাবন্ধ', 'মাসখানেক', 'ভবনটি', 'সংস্কার', 'রং', 'লাগানো', 'নিচতলায়', 'কুসুম', 'কনফেকশনারি', 'নামে', 'দোকান', 'দোকানি', 'লাখ', 'টাকা', 'আগাম', 'দিয়ে', 'ভাড়া', 'নিয়েছেন', 'পাশেই', 'নদীতীরে', 'কেরামত', 'আলী', 'নামের', 'এক', 'ব্যক্তির', 'আংশিক', 'ভেঙে', 'দোতলা', 'ভবন', 'সীমানাদেয়াল', 'মেরামত', 'অপর', 'দোতলা', 'একতলা', 'ভবনে', 'নকিয়া', 'ফ্রুট' ...

# %%
import pickle as pk
inp = open('F:\dataP\\tfidfSorted','rb')

tfidfSorted = pk.load(inp)
inp.close()

# %%
import random
import numpy as np
from sklearn.metrics import f1_score
#Import model for NB
from sklearn.naive_bayes import GaussianNB
from sklearn.model_selection import train_test_split 
from sklearn import tree
from sklearn.metrics import accuracy_score
from sklearn import svm
from sklearn import preprocessing
import itertools
tfIdfSorted = dict(itertools.islice(tfidfSorted.items(),6000))

# create classifier object gor model
model=GaussianNB()

# %%
key = list(tfIdfSorted.keys())
len(key)
# Out:
# 6000

# %%
dataY = data['class'][:1200]

def create_starting_population(individuals, chromosome_length):
    geneNo = chromosome_length
    populationSize = individuals
    # Defining the population size.

    popSize = (populationSize,geneNo) # The population will have sol_per_pop chromosome where each chromosome has num_weights genes.

    #Creating the initial population.
    newPop = np.random.random_integers(low=0, high=1, size=popSize)

    
    return newPop

def calculate_fitness(population):
    keyS = [[] for x in range(10)]
    for j in range(len(population)):
        for i in range(chromosome_length):
            if population[j][i]==1:
                keyS[j].append(key[i])

            
    tfIdff = [[[] for i in range(len(stRem))] for j in range(len(keyS))]
    for i in range(len(stRem)):
        for j in range(len(keyS)):
            for word in keyS[j]:
                    if word in stRem[i]:
                        tfIdff[j][i].append(tfIdfSorted[word])
                    else:
                        tfIdff[j][i].append(0)
    fitnessS =[]
    for j in range(len(keyS)-1):
        dataX = tfIdff[j][:]
        
        try:
            trainX, testX, trainY, testY = train_test_split(dataX, dataY, test_size = 0.2, random_state = 0,stratify=dataY)
            #print(len(trainX),len(trainY),(trainX[0]))
            model.fit(trainX, trainY)

            # make predictions on training data
            predictions_train = model.predict(trainX)
            print(j,'\nTraining Accuracy using DT :',accuracy_score(trainY, predictions_train))

            # make predictions on test data
            predictions_test = model.predict(testX)
            print(j,'\nTest Accuracy using DT:',accuracy_score(testY, predictions_test))
            fitnessS.append(f1_score(testY,predictions_test,average='macro'))
        except:
            fitnessS.append(0)
            
    return fitnessS

def select_individual_by_tournament(population, scores):
    # Get population size
    population_size = len(scores)
    
    # Pick individuals for tournament
    fighter_1 = random.randint(0, population_size-1)
    fighter_2 = random.randint(0, population_size-1)
    
    # Get fitness score for each
    fighter_1_fitness = scores[fighter_1]
    fighter_2_fitness = scores[fighter_2]
    
    # Identify undividual with highest fitness
    # Fighter 1 will win if score are equal
    if fighter_1_fitness >= fighter_2_fitness:
        winner = fighter_1
    else:
        winner = fighter_2
    
    # Return the chromsome of the winner
    return population[winner, :]

def breed_by_crossover(parent_1, parent_2):
    # Get length of chromosome
    chromosome_length = len(parent_1)
    
    # Pick crossover point, avoding ends of chromsome
    crossover_point = random.randint(1,chromosome_length-1)
    
    # Create children. np.hstack joins two arrays
    child_1 = np.hstack((parent_1[0:crossover_point],
                        parent_2[crossover_point:]))
    
    child_2 = np.hstack((parent_2[0:crossover_point],
                        parent_1[crossover_point:]))
    if list(child_1).count(1.0) == 0 or list(child_2).count(1.0) == 0:
        print('piku')
        breed_by_crossover(parent_1, parent_2)
        
    # Return children
    return child_1, child_2

def randomly_mutate_population(population, mutation_probability):
    
    # Apply random mutation
        random_mutation_array = np.random.random(
            size=(population.shape))
        
        random_mutation_boolean = \
            random_mutation_array <= mutation_probability

        population[random_mutation_boolean] = \
        np.logical_not(population[random_mutation_boolean])
        
        # Return mutation population
        return population

# %%
# Set general parameters
chromosome_length = len(tfIdfSorted)
population_size = 10
maximum_generation = 100
best_score_progress = [] # Tracks progress

# Create reference solution 
# (this is used just to illustrate GAs)
#reference = create_reference_solution(chromosome_length)

# Create starting population
population = create_starting_population(population_size, chromosome_length)

# Display best score in starting population
scores = calculate_fitness( population)
best_score = np.max(scores) * 100
print ('Starting best score, percent target: %.1f' %best_score)

# Add starting best score to progress tracker
best_score_progress.append(best_score)



# Now we'll go through the generations of genetic algorithm
for generation in range(maximum_generation):
    print("\nGeneration ",generation,"\n")
    # Create an empty list for new population
    new_population = []
    
    # Create new popualtion generating two children at a time
    for i in range(int(population_size/2)):
        parent_1 = select_individual_by_tournament(population, scores)
        parent_2 = select_individual_by_tournament(population, scores)
        child_1, child_2 = breed_by_crossover(parent_1, parent_2)
        new_population.append(child_1)
        new_population.append(child_2)
    
    # Replace the old population with the new one
    population = np.array(new_population)
    
    # Apply mutation
    mutation_rate = 0.002
    population = randomly_mutate_population(population, mutation_rate)
    for pop in population:
        if list(pop).count(1.0) == 0:
            print('here')
        
    # Score best solution, and add to tracker
    scores = calculate_fitness(population)
    best_score = np.max(scores) * 100
    best_score_progress.append(best_score)

# GA has completed required generation
print ('End best score, percent target: %.1f' %best_score)
# Out:
# C:\Users\USER\Anaconda3\lib\site-packages\ipykernel_launcher.py:11: DeprecationWarning: This function is deprecated. Please call randint(0, 1 + 1) instead
#   # This is added back by InteractiveShellApp.init_path()
# 0
# Training Accuracy using DT : 0.9979166666666667
# 0
# Test Accuracy using DT: 0.7458333333333333
# 1
# Training Accuracy using DT : 0.996875
# 1
# Test Accuracy using DT: 0.75
# 2
# Training Accuracy using DT : 0.996875
# 2
# Test Accuracy using DT: 0.7583333333333333
# 3
# Training Accuracy using DT : 0.9989583333333333
# 3
# Test Accuracy using DT: 0.7791666666666667
# 4
# Training Accuracy using DT : 0.9927083333333333
# 4
# Test Accuracy using DT: 0.7583333333333333
# 5
# Training Accuracy using DT : 0.9979166666666667
# 5
# Test Accuracy using DT: 0.775
# 6
# Training Accuracy using DT : 0.99375
# 6
# Test Accuracy using DT: 0.7708333333333334
# 7
# Training Accuracy using DT : 0.9947916666666666
# 7
# Test Accuracy using DT: 0.7458333333333333
# 8
# Training Accuracy using DT : 0.9958333333333333
# 8
# Test Accuracy using DT: 0.75
# Starting best score, percent target: 78.2
#
# Generation  0
#
# 0
# Training Accuracy using DT : 0.9916666666666667
# 0
# Test Accuracy using DT: 0.7541666666666667
# 1
# Training Accuracy using DT : 0.9979166666666667
# 1
# Test Accuracy using DT: 0.7416666666666667
# 2
# Training Accuracy using DT : 0.99375
# 2
# Test Accuracy using DT: 0.75
# 3
# Training Accuracy using DT : 0.996875
# 3
# Test Accuracy using DT: 0.7791666666666667
# 4
# Training Accuracy using DT : 0.996875
# 4
# Test Accuracy using DT: 0.7791666666666667
# 5
# Training Accuracy using DT : 0.996875
# 5
# Test Accuracy using DT: 0.7791666666666667
# 6
# Training Accuracy using DT : 0.9989583333333333
# 6
# Test Accuracy using DT: 0.775
# 7
# Training Accuracy using DT : 0.9979166666666667
# 7
# Test Accuracy using DT: 0.7416666666666667
# 8
# Training Accuracy using DT : 0.996875
# 8
# Test Accuracy using DT: 0.7583333333333333
#
# Generation  1
#
# 0
# Training Accuracy using DT : 0.9927083333333333
# 0
# Test Accuracy using DT: 0.7833333333333333
# 1
# Training Accuracy using DT : 0.9958333333333333
# 1
# Test Accuracy using DT: 0.75
# 2
# Training Accuracy using DT : 0.9958333333333333
# 2
# Test Accuracy using DT: 0.7541666666666667
# 3
# Training Accuracy using DT : 0.996875
# 3
# Test Accuracy using DT: 0.7791666666666667
# 4
# Training Accuracy using DT : 0.9989583333333333
# 4
# Test Accuracy using DT: 0.7916666666666666
# 5
# Training Accuracy using DT : 0.996875
# 5
# Test Accuracy using DT: 0.7666666666666667
# 6
# Training Accuracy using DT : 0.9989583333333333
# 6
# Test Accuracy using DT: 0.7666666666666667
# 7
# Training Accuracy using DT : 0.9958333333333333
# 7
# Test Accuracy using DT: 0.7833333333333333
# 8
# Training Accuracy using DT : 0.996875
# 8
# Test Accuracy using DT: 0.775
#
# Generation  2
#
# 0
# Training Accuracy using DT : 0.996875
# 0
# Test Accuracy using DT: 0.7708333333333334
# 1
# Training Accuracy using DT : 0.996875
# 1
# Test Accuracy using DT: 0.7958333333333333
# 2
# Training Accuracy using DT : 0.9989583333333333
# 2
# Test Accuracy using DT: 0.7916666666666666
# 3
# Training Accuracy using DT : 0.9989583333333333
# 3
# Test Accuracy using DT: 0.7916666666666666
# 4
# Training Accuracy using DT : 0.996875
# 4
# Test Accuracy using DT: 0.7666666666666667
# 5
# Training Accuracy using DT : 0.996875
# 5
# Test Accuracy using DT: 0.7833333333333333
# 6
# Training Accuracy using DT : 0.9958333333333333
# 6
# Test Accuracy using DT: 0.7833333333333333
# 7
# Training Accuracy using DT : 0.9958333333333333
# 7
# Test Accuracy using DT: 0.7833333333333333
# 8
# Training Accuracy using DT : 0.99375
# 8
# Test Accuracy using DT: 0.7833333333333333
#
# Generation  3
#
# 0
# Training Accuracy using DT : 0.996875
# 0
# Test Accuracy using DT: 0.7625
# 1
# Training Accuracy using DT : 0.9979166666666667
# 1
# Test Accuracy using DT: 0.7916666666666666
# 2
# Training Accuracy using DT : 0.9989583333333333
# 2
# Test Accuracy using DT: 0.7916666666666666
# 3
# Training Accuracy using DT : 0.996875
# 3
# Test Accuracy using DT: 0.7708333333333334
# 4
# Training Accuracy using DT : 0.9979166666666667
# 4
# Test Accuracy using DT: 0.7916666666666666
# 5
# Training Accuracy using DT : 0.9989583333333333
# 5
# Test Accuracy using DT: 0.7916666666666666
# 6
# Training Accuracy using DT : 0.9979166666666667
# 6
# Test Accuracy using DT: 0.7791666666666667
# 7
# Training Accuracy using DT : 0.9979166666666667
# 7
# Test Accuracy using DT: 0.7916666666666666
# 8
# Training Accuracy using DT : 0.9989583333333333
# 8
# Test Accuracy using DT: 0.7958333333333333
#
# Generation  4
#
# 0
# Training Accuracy using DT : 0.9979166666666667
# 0
# Test Accuracy using DT: 0.7916666666666666
# 1
# Training Accuracy using DT : 0.9979166666666667
# 1
# Test Accuracy using DT: 0.7916666666666666
# 2
# Training Accuracy using DT : 0.9979166666666667
# 2
# Test Accuracy using DT: 0.7958333333333333
# 3
# Training Accuracy using DT : 0.9989583333333333
# 3
# Test Accuracy using DT: 0.7916666666666666
# 4
# Training Accuracy using DT : 0.9979166666666667
# 4
# Test Accuracy using DT: 0.7916666666666666
# 5
# Training Accuracy using DT : 0.9989583333333333
# 5
# Test Accuracy using DT: 0.7875
# 6
# Training Accuracy using DT : 0.9989583333333333
# 6
# Test Accuracy using DT: 0.8
# 7
# Training Accuracy using DT : 0.9979166666666667
# 7
# Test Accuracy using DT: 0.7916666666666666
# 8
# Training Accuracy using DT : 0.9979166666666667
# 8
# Test Accuracy using DT: 0.7916666666666666
#
# Generation  5
#
# 0
# Training Accuracy using DT : 0.996875
# 0
# Test Accuracy using DT: 0.7916666666666666
# 1
# Training Accuracy using DT : 0.9989583333333333
# 1
# Test Accuracy using DT: 0.7916666666666666
# 2
# Training Accuracy using DT : 0.9989583333333333
# 2
# Test Accuracy using DT: 0.7958333333333333
# 3
# Training Accuracy using DT : 0.996875
# 3
# Test Accuracy using DT: 0.7916666666666666
# 4
# Training Accuracy using DT : 0.996875
# 4
# Test Accuracy using DT: 0.7875
# 5
# Training Accuracy using DT : 0.9979166666666667
# 5
# Test Accuracy using DT: 0.7916666666666666
# 6
# Training Accuracy using DT : 0.9979166666666667
# 6
# Test Accuracy using DT: 0.7916666666666666
# 7
# Training Accuracy using DT : 0.9989583333333333
# 7
# Test Accuracy using DT: 0.7916666666666666
# 8
# Training Accuracy using DT : 0.9979166666666667
# 8
# Test Accuracy using DT: 0.7958333333333333
#
# Generation  6
#
# 0
# Training Accuracy using DT : 0.9989583333333333
# 0
# Test Accuracy using DT: 0.7958333333333333
# 1
# Training Accuracy using DT : 0.9979166666666667
# 1
# Test Accuracy using DT: 0.7958333333333333
# 2
# Training Accuracy using DT : 0.9979166666666667
# 2
# Test Accuracy using DT: 0.7958333333333333
# 3
# Training Accuracy using DT : 0.996875
# 3
# Test Accuracy using DT: 0.7916666666666666
# 4
# Training Accuracy using DT : 0.9979166666666667
# 4
# Test Accuracy using DT: 0.7916666666666666
# 5
# Training Accuracy using DT : 0.9979166666666667
# 5
# Test Accuracy using DT: 0.7916666666666666
# 6
# Training Accuracy using DT : 0.996875
# 6
# Test Accuracy using DT: 0.7916666666666666
# 7
# Training Accuracy using DT : 0.9979166666666667
# 7
# Test Accuracy using DT: 0.7875
# 8
# Training Accuracy using DT : 0.9979166666666667
# 8
# Test Accuracy using DT: 0.7958333333333333
#
# Generation  7
#
# 0
# Training Accuracy using DT : 0.9979166666666667
# 0
# Test Accuracy using DT: 0.7958333333333333
# 1
# Training Accuracy using DT : 0.9979166666666667
# 1
# Test Accuracy using DT: 0.7916666666666666
# 2
# Training Accuracy using DT : 0.9989583333333333
# 2
# Test Accuracy using DT: 0.7958333333333333
# 3
# Training Accuracy using DT : 0.996875
# 3
# Test Accuracy using DT: 0.7958333333333333
# 4
# Training Accuracy using DT : 0.9979166666666667
# 4
# Test Accuracy using DT: 0.7958333333333333
# 5
# Training Accuracy using DT : 0.9979166666666667
# 5
# Test Accuracy using DT: 0.7916666666666666
# 6
# Training Accuracy using DT : 0.9979166666666667
# 6
# Test Accuracy using DT: 0.7958333333333333
# 7
# Training Accuracy using DT : 0.9979166666666667
# 7
# Test Accuracy using DT: 0.7958333333333333
# 8
# Training Accuracy using DT : 0.9979166666666667
# 8
# Test Accuracy using DT: 0.7958333333333333
#
# Generation  8
#
# 0
# Training Accuracy using DT : 0.9979166666666667
# 0
# Test Accuracy using DT: 0.8
# 1
# Training Accuracy using DT : 0.9979166666666667
# 1
# Test Accuracy using DT: 0.7958333333333333
# 2
# Training Accuracy using DT : 0.9989583333333333
# 2
# Test Accuracy using DT: 0.8
# 3
# Training Accuracy using DT : 0.9989583333333333
# 3
# Test Accuracy using DT: 0.7875
# 4
# Training Accuracy using DT : 0.996875
# 4
# Test Accuracy using DT: 0.7916666666666666
# 5
# Training Accuracy using DT : 0.9979166666666667
# 5
# Test Accuracy using DT: 0.7875
# 6
# Training Accuracy using DT : 0.9989583333333333
# 6
# Test Accuracy using DT: 0.7958333333333333
# 7
# Training Accuracy using DT : 0.9979166666666667
# 7
# Test Accuracy using DT: 0.7916666666666666
# 8
# Training Accuracy using DT : 0.9989583333333333
# 8
# Test Accuracy using DT: 0.7958333333333333
#
# Generation  9
#
# 0
# Training Accuracy using DT : 0.9989583333333333
# 0
# Test Accuracy using DT: 0.7875
# 1
# Training Accuracy using DT : 0.9989583333333333
# 1
# Test Accuracy using DT: 0.8041666666666667
# 2
# Training Accuracy using DT : 0.9979166666666667
# 2
# Test Accuracy using DT: 0.8
# 3
# Training Accuracy using DT : 0.9989583333333333
# 3
# Test Accuracy using DT: 0.8
# 4
# Training Accuracy using DT : 0.9979166666666667
# 4
# Test Accuracy using DT: 0.8
# 5
# Training Accuracy using DT : 0.9989583333333333
# 5
# Test Accuracy using DT: 0.8
# 6
# Training Accuracy using DT : 0.9989583333333333
# 6
# Test Accuracy using DT: 0.7916666666666666
# 7
# Training Accuracy using DT : 0.9979166666666667
# 7
# Test Accuracy using DT: 0.7958333333333333
# 8
# Training Accuracy using DT : 0.9989583333333333
# 8
# Test Accuracy using DT: 0.8
#
# Generation  10
#
# 0
# Training Accuracy using DT : 0.9989583333333333
# 0
# Test Accuracy using DT: 0.8
# 1
# Training Accuracy using DT : 0.9989583333333333
# 1
# Test Accuracy using DT: 0.8
# 2
# Training Accuracy using DT : 0.9979166666666667
# 2
# Test Accuracy using DT: 0.8
# 3
# Training Accuracy using DT : 0.9989583333333333
# 3
# Test Accuracy using DT: 0.8
# 4
# Training Accuracy using DT : 0.9989583333333333
# 4
# Test Accuracy using DT: 0.8041666666666667
# 5
# Training Accuracy using DT : 0.9979166666666667
# 5
# Test Accuracy using DT: 0.8041666666666667
# 6
# Training Accuracy using DT : 0.9979166666666667
# 6
# Test Accuracy using DT: 0.8
# 7
# Training Accuracy using DT : 0.9979166666666667
# 7
# Test Accuracy using DT: 0.7958333333333333
# 8
# Training Accuracy using DT : 0.9979166666666667
# 8
# Test Accuracy using DT: 0.8
#
# Generation  11
#
# 0
# Training Accuracy using DT : 0.9979166666666667
# 0
# Test Accuracy using DT: 0.8041666666666667
# 1
# Training Accuracy using DT : 0.9979166666666667
# 1
# Test Accuracy using DT: 0.8041666666666667
# 2
# Training Accuracy using DT : 0.9989583333333333
# 2
# Test Accuracy using DT: 0.8041666666666667
# 3
# Training Accuracy using DT : 0.9989583333333333
# 3
# Test Accuracy using DT: 0.8
# 4
# Training Accuracy using DT : 0.9979166666666667
# 4
# Test Accuracy using DT: 0.8041666666666667
# 5
# Training Accuracy using DT : 0.9979166666666667
# 5
# Test Accuracy using DT: 0.8041666666666667
# 6
# Training Accuracy using DT : 0.9979166666666667
# 6
# Test Accuracy using DT: 0.
# 6
# Training Accuracy using DT : 0.9947916666666666
# 6
# Test Accuracy using DT: 0.8333333333333334
# 7
# Training Accuracy using DT : 0.9958333333333333
# 7
# Test Accuracy using DT: 0.8333333333333334
# 8
# Training Accuracy using DT : 0.9958333333333333
# 8
# Test Accuracy using DT: 0.8375
#
# Generation  53
#
# 0
# Training Accuracy using DT : 0.9947916666666666
# 0
# Test Accuracy using DT: 0.8375
# 1
# Training Accuracy using DT : 0.996875
# 1
# Test Accuracy using DT: 0.8375
# 2
# Training Accuracy using DT : 0.9947916666666666
# 2
# Test Accuracy using DT: 0.8375
# 3
# Training Accuracy using DT : 0.9958333333333333
# 3
# Test Accuracy using DT: 0.8333333333333334
# 4
# Training Accuracy using DT : 0.9958333333333333
# 4
# Test Accuracy using DT: 0.8375
# 5
# Training Accuracy using DT : 0.99375
# 5
# Test Accuracy using DT: 0.8375
# 6
# Training Accuracy using DT : 0.99375
# 6
# Test Accuracy using DT: 0.8375
# 7
# Training Accuracy using DT : 0.99375
# 7
# Test Accuracy using DT: 0.8333333333333334
# 8
# Training Accuracy using DT : 0.9958333333333333
# 8
# Test Accuracy using DT: 0.8375
#
# Generation  54
#
# 0
# Training Accuracy using DT : 0.9979166666666667
# 0
# Test Accuracy using DT: 0.8375
# 1
# Training Accuracy using DT : 0.996875
# 1
# Test Accuracy using DT: 0.8375
# 2
# Training Accuracy using DT : 0.9947916666666666
# 2
# Test Accuracy using DT: 0.8375
# 3
# Training Accuracy using DT : 0.9958333333333333
# 3
# Test Accuracy using DT: 0.8375
# 4
# Training Accuracy using DT : 0.99375
# 4
# Test Accuracy using DT: 0.8375
# 5
# Training Accuracy using DT : 0.9958333333333333
# 5
# Test Accuracy using DT: 0.8375
# 6
# Training Accuracy using DT : 0.9958333333333333
# 6
# Test Accuracy using DT: 0.8375
# 7
# Training Accuracy using DT : 0.996875
# 7
# Test Accuracy using DT: 0.8375
# 8
# Training Accuracy using DT : 0.996875
# 8
# Test Accuracy using DT: 0.8375
#
# Generation  55
#
# 0
# Training Accuracy using DT : 0.9958333333333333
# 0
# Test Accuracy using DT: 0.8375
# 1
# Training Accuracy using DT : 0.99375
# 1
# Test Accuracy using DT: 0.8375
# 2
# Training Accuracy using DT : 0.9958333333333333
# 2
# Test Accuracy using DT: 0.8375
# 3
# Training Accuracy using DT : 0.996875
# 3
# Test Accuracy using DT: 0.8333333333333334
# 4
# Training Accuracy using DT : 0.996875
# 4
# Test Accuracy using DT: 0.8333333333333334
# 5
# Training Accuracy using DT : 0.996875
# 5
# Test Accuracy using DT: 0.8375
# 6
# Training Accuracy using DT : 0.9947916666666666
# 6
# Test Accuracy using DT: 0.8375
# 7
# Training Accuracy using DT : 0.9947916666666666
# 7
# Test Accuracy using DT: 0.8375
# 8
# Training Accuracy using DT : 0.9958333333333333
# 8
# Test Accuracy using DT: 0.8375
#
# Generation  56
#
# 0
# Training Accuracy using DT : 0.99375
# 0
# Test Accuracy using DT: 0.8375
# 1
# Training Accuracy using DT : 0.9947916666666666
# 1
# Test Accuracy using DT: 0.8333333333333334
# 2
# Training Accuracy using DT : 0.9947916666666666
# 2
# Test Accuracy using DT: 0.8333333333333334
# 3
# Training Accuracy using DT : 0.996875
# 3
# Test Accuracy using DT: 0.8375
# 4
# Training Accuracy using DT : 0.9947916666666666
# 4
# Test Accuracy using DT: 0.8416666666666667
# 5
# Training Accuracy using DT : 0.9947916666666666
# 5
# Test Accuracy using DT: 0.8375
# 6
# ...
# 2
# Test Accuracy using DT: 0.8458333333333333
# 3
# Training Accuracy using DT : 0.9947916666666666
# 3
# Test Accuracy using DT: 0.8416666666666667
# 4
# Training Accuracy using DT : 0.99375
# 4
# Test Accuracy using DT: 0.8458333333333333
# 5
# Training Accuracy using DT : 0.9947916666666666
# 5
# Test Accuracy using DT: 0.8458333333333333
# 6
# Training Accuracy using DT : 0.9947916666666666
# 6
# Test Accuracy using DT: 0.8458333333333333
# 7
# Training Accuracy using DT : 0.99375
# 7
# Test Accuracy using DT: 0.8416666666666667
# 8
# Training Accuracy using DT : 0.99375
# 8
# Test Accuracy using DT: 0.8458333333333333
#
# Generation  81
#
# 0
# Training Accuracy using DT : 0.99375
# 0
# Test Accuracy using DT: 0.8458333333333333
# 1
# Training Accuracy using DT : 0.9947916666666666
# 1
# Test Accuracy using DT: 0.8458333333333333
# 2
# Training Accuracy using DT : 0.9947916666666666
# 2
# Test Accuracy using DT: 0.8458333333333333
# 3
# Training Accuracy using DT : 0.9947916666666666
# 3
# Test Accuracy using DT: 0.8458333333333333
# 4
# Training Accuracy using DT : 0.9947916666666666
# 4
# Test Accuracy using DT: 0.8458333333333333
# 5
# Training Accuracy using DT : 0.9947916666666666
# 5
# Test Accuracy using DT: 0.8416666666666667
# 6
# Training Accuracy using DT : 0.9947916666666666
# 6
# Test Accuracy using DT: 0.8458333333333333
# 7
# Training Accuracy using DT : 0.9947916666666666
# 7
# Test Accuracy using DT: 0.8458333333333333
# 8
# Training Accuracy using DT : 0.9947916666666666
# 8
# Test Accuracy using DT: 0.8458333333333333
#
# Generation  82
#
# 0
# Training Accuracy using DT : 0.9947916666666666
# 0
# Test Accuracy using DT: 0.8458333333333333
# 1
# Training Accuracy using DT : 0.9947916666666666
# 1
# Test Accuracy using DT: 0.8416666666666667
# 2
# Training Accuracy using DT : 0.9947916666666666
# 2
# Test Accuracy using DT: 0.8458333333333333
# 3
# Training Accuracy using DT : 0.99375
# 3
# Test Accuracy using DT: 0.8458333333333333
# 4
# Training Accuracy using DT : 0.99375
# 4
# Test Accuracy using DT: 0.8458333333333333
# 5
# Training Accuracy using DT : 0.9947916666666666
# 5
# Test Accuracy using DT: 0.8458333333333333
# 6
# Training Accuracy using DT : 0.9947916666666666
# 6
# Test Accuracy using DT: 0.8416666666666667
# 7
# Training Accuracy using DT : 0.9947916666666666
# 7
# Test Accuracy using DT: 0.8458333333333333
# 8
# Training Accuracy using DT : 0.9947916666666666
# 8
# Test Accuracy using DT: 0.8458333333333333
#
# Generation  83
#
# 0
# Training Accuracy using DT : 0.9947916666666666
# 0
# Test Accuracy using DT: 0.8458333333333333
# 1
# Training Accuracy using DT : 0.9947916666666666
# 1
# Test Accuracy using DT: 0.8458333333333333
# 2
# Training Accuracy using DT : 0.9947916666666666
# 2
# Test Accuracy using DT: 0.8458333333333333
# 3
# Training Accuracy using DT : 0.99375
# 3
# Test Accuracy using DT: 0.8458333333333333
# 4
# Training Accuracy using DT : 0.99375
# 4
# Test Accuracy using DT: 0.8458333333333333
# 5
# Training Accuracy using DT : 0.99375
# 5
# Test Accuracy using DT: 0.8416666666666667
# 6
# Training Accuracy using DT : 0.9947916666666666
# 6
# Test Accuracy using DT: 0.8458333333333333
# 7
# Training Accuracy using DT : 0.9947916666666666
# 7
# Test Accuracy using DT: 0.8458333333333333
# 8
# Training Accuracy using DT : 0.9947916666666666
# 8
# Test Accuracy using DT: 0.8458333333333333
#
# Generation  84
#
# 0
# Training Accuracy using DT : 0.9947916666666666
# 0
# Test Accuracy using DT: 0.8458333333333333
# 1
# Training Accuracy using DT : 0.99375
# 1
# Test Accuracy using DT: 0.8458333333333333
# 2
# Training Accuracy using DT : 0.9958333333333333
# 2
# Test Accuracy using DT: 0.8458333333333333
# 3
# Training Accuracy using DT : 0.99375
# 3
# Test Accuracy using DT: 0.8458333333333333
# 4
# Training Accuracy using DT : 0.99375
# 4
# Test Accuracy using DT: 0.85
# 5
# Training Accuracy using DT : 0.9947916666666666
# 5
# Test Accuracy using DT: 0.8458333333333333
# 6
# Training Accuracy using DT : 0.9947916666666666
# 6
# Test Accuracy using DT: 0.8416666666666667
# 7
# Training Accuracy using DT : 0.99375
# 7
# Test Accuracy using DT: 0.8458333333333333
# 8
# Training Accuracy using DT : 0.9947916666666666
# 8
# Test Accuracy using DT: 0.8458333333333333
#
# Generation  85
#
# 0
# Training Accuracy using DT : 0.9947916666666666
# 0
# Test Accuracy using DT: 0.8458333333333333
# 1
# Training Accuracy using DT : 0.9947916666666666
# 1
# Test Accuracy using DT: 0.8458333333333333
# 2
# Training Accuracy using DT : 0.99375
# 2
# Test Accuracy using DT: 0.8458333333333333
# 3
# Training Accuracy using DT : 0.99375
# 3
# Test Accuracy using DT: 0.8458333333333333
# 4
# Training Accuracy using DT : 0.9947916666666666
# 4
# Test Accuracy using DT: 0.85
# 5
# Training Accuracy using DT : 0.99375
# 5
# Test Accuracy using DT: 0.8458333333333333
# 6
# Training Accuracy using DT : 0.99375
# 6
# Test Accuracy using DT: 0.85
# 7
# Training Accuracy using DT : 0.99375
# 7
# Test Accuracy using DT: 0.8458333333333333
# 8
# Training Accuracy using DT : 0.9947916666666666
# 8
# Test Accuracy using DT: 0.8458333333333333
#
# Generation  86
#
# 0
# Training Accuracy using DT : 0.9947916666666666
# 0
# Test Accuracy using DT: 0.8458333333333333
# 1
# Training Accuracy using DT : 0.9947916666666666
# 1
# Test Accuracy using DT: 0.8416666666666667
# 2
# Training Accuracy using DT : 0.9947916666666666
# 2
# Test Accuracy using DT: 0.8458333333333333
# 3
# Training Accuracy using DT : 0.99375
# 3
# Test Accuracy using DT: 0.8458333333333333
# 4
# Training Accuracy using DT : 0.9947916666666666
# 4
# Test Accuracy using DT: 0.85
# 5
# Training Accuracy using DT : 0.9958333333333333
# 5
# Test Accuracy using DT: 0.85
# 6
# Training Accuracy using DT : 0.9947916666666666
# 6
# Test Accuracy using DT: 0.8458333333333333
# 7
# Training Accuracy using DT : 0.9947916666666666
# 7
# Test Accuracy using DT: 0.85
# 8
# Training Accuracy using DT : 0.9947916666666666
# 8
# Test Accuracy using DT: 0.8458333333333333
#
# Generation  87
#
# 0
# Training Accuracy using DT : 0.9958333333333333
# 0
# Test Accuracy using DT: 0.85
# 1
# Training Accuracy using DT : 0.9958333333333333
# 1
# Test Accuracy using DT: 0.85
# 2
# Training Accuracy using DT : 0.9947916666666666
# 2
# Test Accuracy using DT: 0.8458333333333333
# 3
# Training Accuracy using DT : 0.9958333333333333
# 3
# Test Accuracy using DT: 0.8458333333333333
# 4
# Training Accuracy using DT : 0.9947916666666666
# 4
# Test Accuracy using DT: 0.8458333333333333
# 5
# Training Accuracy using DT : 0.9958333333333333
# 5
# Test Accuracy using DT: 0.8458333333333333
# 6
# Training Accuracy using DT : 0.9947916666666666
# 6
# Test Accuracy using DT: 0.85
# 7
# Training Accuracy using DT : 0.996875
# 7
# Test Accuracy using DT: 0.85
# 8
# Training Accuracy using DT : 0.9958333333333333
# 8
# Test Accuracy using DT: 0.85
#
# Generation  88
#
# 0
# Training Accuracy using DT : 0.9958333333333333
# 0
# Test Accuracy using DT: 0.85
# 1
# Training Accuracy using DT : 0.996875
# 1
# Test Accuracy using DT: 0.85
# 2
# Training Accuracy using DT : 0.9958333333333333
# 2
# Test Accuracy using DT: 0.8458333333333333
# 3
# Training Accuracy using DT : 0.99375
# 3
# Test Accuracy using DT: 0.85
# 4
# Training Accuracy using DT : 0.9947916666666666
# 4
# Test Accuracy using DT: 0.8458333333333333
# 5
# Training Accuracy using DT : 0.9958333333333333
# 5
# Test Accuracy using DT: 0.8458333333333333
# 6
# Training Accuracy using DT : 0.9958333333333333
# 6
# Test Accuracy using DT: 0.85
# 7
# Training Accuracy using DT : 0.9947916666666666
# 7
# Test Accuracy using DT: 0.8458333333333333
# 8
# Training Accuracy using DT : 0.9947916666666666
# 8
# Test Accuracy using DT: 0.8416666666666667
#
# Generation  89
#
# 0
# Training Accuracy using DT : 0.99375
# 0
# Test Accuracy using DT: 0.85
# 1
# Training Accuracy using DT : 0.99375
# 1
# Test Accuracy using DT: 0.85
# 2
# Training Accuracy using DT : 0.9947916666666666
# 2
# Test Accuracy using DT: 0.85
# 3
# Training Accuracy using DT : 0.996875
# 3
# Test Accuracy using DT: 0.8458333333333333
# 4
# Training Accuracy using DT : 0.9958333333333333
# 4
# Test Accuracy using DT: 0.8416666666666667
# 5
# Training Accuracy using DT : 0.9958333333333333
# 5
# Test Accuracy using DT: 0.8416666666666667
# 6
# Training Accuracy using DT : 0.9947916666666666
# 6
# Test Accuracy using DT: 0.8458333333333333
# 7
# Training Accuracy using DT : 0.9947916666666666
# 7
# Test Accuracy using DT: 0.8458333333333333
# 8
# Training Accuracy using DT : 0.996875
# 8
# Test Accuracy using DT: 0.8458333333333333
#
# Generation  90
#
# 0
# Training Accuracy using DT : 0.9927083333333333
# 0
# Test Accuracy using DT: 0.85
# 1
# Training Accuracy using DT : 0.9947916666666666
# 1
# Test Accuracy using DT: 0.85
# 2
# Training Accuracy using DT : 0.9947916666666666
# 2
# Test Accuracy using DT: 0.85
# 3
# Training Accuracy using DT : 0.99375
# 3
# Test Accuracy using DT: 0.8458333333333333
# 4
# Training Accuracy using DT : 0.9947916666666666
# 4
# Test Accuracy using DT: 0.85
# 5
# Training Accuracy using DT : 0.9947916666666666
# 5
# Test Accuracy using DT: 0.85
# 6
# Training Accuracy using DT : 0.9947916666666666
# 6
# Test Accuracy using DT: 0.85
# 7
# Training Accuracy using DT : 0.9958333333333333
# 7
# Test Accuracy using DT: 0.8458333333333333
# 8
# Training Accuracy using DT : 0.9947916666666666
# 8
# Test Accuracy using DT: 0.8416666666666667
#
# Generation  91
#
# 0
# Training Accuracy using DT : 0.9947916666666666
# 0
# Test Accuracy using DT: 0.85
# 1
# Training Accuracy using DT : 0.9947916666666666
# 1
# Test Accuracy using DT: 0.85
# 2
# Training Accuracy using DT : 0.99375
# 2
# Test Accuracy using DT: 0.8416666666666667
# 3
# Training Accuracy using DT : 0.9947916666666666
# 3
# Test Accuracy using DT: 0.85
# 4
# Training Accuracy using DT : 0.9927083333333333
# 4
# Test Accuracy using DT: 0.85
# 5
# Training Accuracy using DT : 0.9947916666666666
# 5
# Test Accuracy using DT: 0.85
# 6
# Training Accuracy using DT : 0.99375
# 6
# Test Accuracy using DT: 0.85
# 7
# Training Accuracy using DT : 0.99375
# 7
# Test Accuracy using DT: 0.85
# 8
# Training Accuracy using DT : 0.9927083333333333
# 8
# Test Accuracy using DT: 0.85
#
# Generation  92
#
# 0
# Training Accuracy using DT : 0.9947916666666666
# 0
# Test Accuracy using DT: 0.85
# 1
# Training Accuracy using DT : 0.99375
# 1
# Test Accuracy using DT: 0.85
# 2
# Training Accuracy using DT : 0.99375
# 2
# Test Accuracy using DT: 0.8458333333333333
# 3
# Training Accuracy using DT : 0.9927083333333333
# 3
# Test Accuracy using DT: 0.85
# 4
# Training Accuracy using DT : 0.9947916666666666
# 4
# Test Accuracy using DT: 0.85
# 5
# Training Accuracy using DT : 0.9927083333333333
# 5
# Test Accuracy using DT: 0.85
# 6
# Training Accuracy using DT : 0.9947916666666666
# 6
# Test Accuracy using DT: 0.85
# 7
# Training Accuracy using DT : 0.9947916666666666
# 7
# Test Accuracy using DT: 0.85
# 8
# Training Accuracy using DT : 0.9947916666666666
# 8
# Test Accuracy using DT: 0.85
#
# Generation  93
#
# 0
# Training Accuracy using DT : 0.9927083333333333
# 0
# Test Accuracy using DT: 0.85
# 1
# Training Accuracy using DT : 0.9927083333333333
# 1
# Test Accuracy using DT: 0.85
# 2
# Training Accuracy using DT : 0.9947916666666666
# 2
# Test Accuracy using DT: 0.85
# 3
# Training Accuracy using DT : 0.9947916666666666
# 3
# Test Accuracy using DT: 0.85
# 4
# Training Accuracy using DT : 0.9958333333333333
# 4
# Test Accuracy using DT: 0.8458333333333333
# 5
# Training Accuracy using DT : 0.9927083333333333
# 5
# Test Accuracy using DT: 0.85
# 6
# Training Accuracy using DT : 0.9947916666666666
# 6
# Test Accuracy using DT: 0.8458333333333333
# 7
# Training Accuracy using DT : 0.9947916666666666
# 7
# Test Accuracy using DT: 0.85
# 8
# Training Accuracy using DT : 0.9927083333333333
# 8
# Test Accuracy using DT: 0.85
#
# Generation  94
#
# 0
# Training Accuracy using DT : 0.9927083333333333
# 0
# Test Accuracy using DT: 0.85
# 1
# Training Accuracy using DT : 0.9927083333333333
# 1
# Test Accuracy using DT: 0.85
# 2
# Training Accuracy using DT : 0.9927083333333333
# 2
# Test Accuracy using DT: 0.8458333333333333
# 3
# Training Accuracy using DT : 0.99375
# 3
# Test Accuracy using DT: 0.85
# 4
# Training Accuracy using DT : 0.9947916666666666
# 4
# Test Accuracy using DT: 0.85
# 5
# Training Accuracy using DT : 0.9947916666666666
# 5
# Test Accuracy using DT: 0.85
# 6
# Training Accuracy using DT : 0.99375
# 6
# Test Accuracy using DT: 0.85
# 7
# Training Accuracy using DT : 0.99375
# 7
# Test Accuracy using DT: 0.85
# 8
# Training Accuracy using DT : 0.9947916666666666
# 8
# Test Accuracy using DT: 0.8458333333333333
#
# Generation  95
#
# 0
# Training Accuracy using DT : 0.9947916666666666
# 0
# Test Accuracy using DT: 0.85
# 1
# Training Accuracy using DT : 0.9958333333333333
# 1
# Test Accuracy using DT: 0.85
# 2
# Training Accuracy using DT : 0.9927083333333333
# 2
# Test Accuracy using DT: 0.85
# 3
# Training Accuracy using DT : 0.9958333333333333
# 3
# Test Accuracy using DT: 0.8458333333333333
# 4
# Training Accuracy using DT : 0.9927083333333333
# 4
# Test Accuracy using DT: 0.85
# 5
# Training Accuracy using DT : 0.9947916666666666
# 5
# Test Accuracy using DT: 0.85
# 6
# Training Accuracy using DT : 0.99375
# 6
# Test Accuracy using DT: 0.8458333333333333
# 7
# Training Accuracy using DT : 0.99375
# 7
# Test Accuracy using DT: 0.85
# 8
# Training Accuracy using DT : 0.9947916666666666
# 8
# Test Accuracy using DT: 0.85
#
# Generation  96
#
# 0
# Training Accuracy using DT : 0.9927083333333333
# 0
# Test Accuracy using DT: 0.85
# 1
# Training Accuracy using DT : 0.9947916666666666
# 1
# Test Accuracy using DT: 0.85
# 2
# Training Accuracy using DT : 0.99375
# 2
# Test Accuracy using DT: 0.85
# 3
# Training Accuracy using DT : 0.9947916666666666
# 3
# Test Accuracy using DT: 0.85
# 4
# Training Accuracy using DT : 0.99375
# 4
# Test Accuracy using DT: 0.85
# 5
# Training Accuracy using DT : 0.99375
# 5
# Test Accuracy using DT: 0.85
# 6
# Training Accuracy using DT : 0.9927083333333333
# 6
# Test Accuracy using DT: 0.85
# 7
# Training Accuracy using DT : 0.9947916666666666
# 7
# Test Accuracy using DT: 0.85
# 8
# Training Accuracy using DT : 0.9947916666666666
# 8
# Test Accuracy using DT: 0.8541666666666666
#
# Generation  97
#
# 0
# Training Accuracy using DT : 0.99375
# 0
# Test Accuracy using DT: 0.8541666666666666
# 1
# Training Accuracy using DT : 0.9947916666666666
# 1
# Test Accuracy using DT: 0.85
# 2
# Training Accuracy using DT : 0.9947916666666666
# 2
# Test Accuracy using DT: 0.85
# 3
# Training Accuracy using DT : 0.99375
# 3
# Test Accuracy using DT: 0.85
# 4
# Training Accuracy using DT : 0.9947916666666666
# 4
# Test Accuracy using DT: 0.8541666666666666
# 5
# Training Accuracy using DT : 0.9947916666666666
# 5
# Test Accuracy using DT: 0.85
# 6
# Training Accuracy using DT : 0.9947916666666666
# 6
# Test Accuracy using DT: 0.8541666666666666
# 7
# Training Accuracy using DT : 0.9979166666666667
# 7
# Test Accuracy using DT: 0.85
# 8
# Training Accuracy using DT : 0.9958333333333333
# 8
# Test Accuracy using DT: 0.85
#
# Generation  98
#
# 0
# Training Accuracy using DT : 0.9947916666666666
# 0
# Test Accuracy using DT: 0.8541666666666666
# 1
# Training Accuracy using DT : 0.9947916666666666
# 1
# Test Accuracy using DT: 0.8541666666666666
# 2
# Training Accuracy using DT : 0.9947916666666666
# 2
# Test Accuracy using DT: 0.85
# 3
# Training Accuracy using DT : 0.9947916666666666
# 3
# Test Accuracy using DT: 0.85
# 4
# Training Accuracy using DT : 0.9958333333333333
# 4
# Test Accuracy using DT: 0.8541666666666666
# 5
# Training Accuracy using DT : 0.9947916666666666
# 5
# Test Accuracy using DT: 0.8541666666666666
# 6
# Training Accuracy using DT : 0.99375
# 6
# Test Accuracy using DT: 0.8541666666666666
# 7
# Training Accuracy using DT : 0.9958333333333333
# 7
# Test Accuracy using DT: 0.8458333333333333
# 8
# Training Accuracy using DT : 0.9947916666666666
# 8
# Test Accuracy using DT: 0.85
#
# Generation  99
#
# 0
# Training Accuracy using DT : 0.9947916666666666
# 0
# Test Accuracy using DT: 0.8541666666666666
# 1
# Training Accuracy using DT : 0.9947916666666666
# 1
# Test Accuracy using DT: 0.8541666666666666
# 2
# Training Accuracy using DT : 0.9947916666666666
# 2
# Test Accuracy using DT: 0.85
# 3
# Training Accuracy using DT : 0.9947916666666666
# 3
# Test Accuracy using DT: 0.8541666666666666
# 4
# Training Accuracy using DT : 0.9927083333333333
# 4
# Test Accuracy using DT: 0.85
# 5
# Training Accuracy using DT : 0.9947916666666666
# 5
# Test Accuracy using DT: 0.8541666666666666
# 6
# Training Accuracy using DT : 0.9947916666666666
# 6
# Test Accuracy using DT: 0.85
# 7
# Training Accuracy using DT : 0.9947916666666666
# 7
# Test Accuracy using DT: 0.85
# 8
# Training Accuracy using DT : 0.9947916666666666
# 8
# Test Accuracy using DT: 0.8541666666666666
# End best score, percent target: 85.7

# %%
# Plot progress
import matplotlib.pyplot as plt
# %matplotlib inline
plt.plot(best_score_progress)
plt.xlabel('Generation')
plt.ylabel('Best score (% target)')
plt.show()
print(list(population[0]).count(1))

print(population[0])
print(best_score_progress)
# Out:
# 3043
# [0 1 1 ... 1 0 1]
# [78.17713761986208, 78.65510007421773, 79.33053882059433, 79.81216600229172, 79.75406299291897, 80.11422054614275, 79.75406299291897, 79.75406299291897, 79.863159830189, 80.3510177665662, 80.6377734510975, 80.75474338648951, 80.75474338648951, 81.17149707626949, 81.17149707626949, 81.48982498982498, 81.18614687087114, 81.57381443405193, 81.59704162959135, 81.59704162959135, 81.93568568568568, 81.93568568568568, 81.93717768401312, 81.93717768401312, 82.34598684799673, 82.37469825311263, 82.37469825311263, 82.43042843243833, 82.43042843243833, 82.79940418285739, 82.72008497209487, 82.73749701246312, 82.73749701246312, 82.77075151758697, 82.77075151758697, 82.81223222198902, 82.81223222198902, 82.81223222198902, 83.18448793132337, 83.18448793132337, 83.13523377862094, 83.51425865644293, 83.51425865644293, 83.54897019235736, 83.54897019235736, 83.54897019235736, 83.51425865644293, 83.54808529492074, 83.86961160659482, 83.86961160659482, 83.86961160659482, 83.86961160659482, 83.86961160659482, 83.86961160659482, 83.86961160659482, 83.90185555566774, 83.90185555566774, 84.2176371303255, 84.61772330949856, 84.73451114719951, 84.73451114719951, 84.73451114719951, 84.73451114719951, 85.14869919250224, 85.14869919250224, 84.80608316785195, 84.73451114719951, 85.07962185231935, 85.07962185231935, 85.07962185231935, 84.7642048728091, 84.7642048728091, 84.7642048728091, 84.7642048728091, 85.11765290965162, 85.11765290965162, 85.11765290965162, 84.7642048728091, 84.79956226335318, 84.7642048728091, 84.7642048728091, 84.7642048728091, 84.7642048728091, 84.7642048728091, 84.7642048728091, 85.27600487091047, 85.27600487091047, 85.27600487091047, 85.29027865837656, 85.29027865837656, 85.27600487091047, 85.27600487091047, 85.31191775614914, 85.35410432774746, 85.31191775614914, 85.31191775614914, 85.35410432774746, 85.66360177013527, 85.66360177013527, 85.70407461889424, 85.70407461889424]

# %%
import pickle as pk
import pickle
out = open("F:/best_Score",'wb')

pickle.dump(best_score_progress,out)
out.close()

# %%
dataF = pd.DataFrame()
dataF['best6k'] = best_score_progress

# %%
dataF.shape
len(key)
# Out:
# 6000

# %%
# dataF.to_csv("F:/Best_score6k.csv")

# %%
tfIdfFl = [[] for i in range(len(stRem))] 

keyF = []
for j in range(len(population[0])):
    if population[0][j]==1:
        keyF.append(key[j])

len(keyF)
# Out:
# 3043

# %%
for i in range(len(stRem)):
    for word in keyF:
        if word in stRem[i]:
            tfIdfFl[i].append(tfIdfSorted[word])
        else:
            tfIdfFl[i].append(0)

# %%
keyData = pd.DataFrame()
keyData['key']=keyF

# %%
keyData.shape
# Out:
# (3043, 1)

# %%
keyData.to_csv("F:\\dataP\\keyF6k.csv",encoding='utf-8-sig',mode='w')

# %%
from sklearn.model_selection import train_test_split 

from sklearn import svm
from sklearn import preprocessing


dataX = tfIdfFl
dataY = data['class']
print(len(dataX))

trainX, testX, trainY, testY = train_test_split(dataX, dataY, test_size = 0.3, random_state = 0,stratify=dataY)
# Out:
# 1200

# %%
print(len(trainX))
print(len(trainY))
print(len(testX))
print(len(testY))
# Out:
# 840
# 840
# 360
# 360

# %%
#Import model for NB
from sklearn.naive_bayes import GaussianNB,MultinomialNB
from sklearn.metrics import accuracy_score
# create classifier object gor model
model=GaussianNB()

# train the model with fit function
model.fit(trainX, trainY)
   
# make predictions on training data
predictions_train = model.predict(trainX)
print('\nTraining Accuracy using NB :',accuracy_score(trainY, predictions_train))

# make predictions on test data
predictions_test = model.predict(testX)
print('\nTest Accuracy using NB :',accuracy_score(testY, predictions_test))


from sklearn.metrics import classification_report, confusion_matrix, accuracy_score
print('\nConfusion matrix:\n',confusion_matrix(trainY,predictions_train))
print(classification_report(trainY,predictions_train))  

print('\nConfusion matrix:\n',confusion_matrix(testY,predictions_test))
print(classification_report(testY,predictions_test))
# Out:
# Training Accuracy using NB : 0.9976190476190476
#
# Test Accuracy using NB : 0.8166666666666667
#
# Confusion matrix:
#  [[138   1   0   1   0   0]
#  [  0 140   0   0   0   0]
#  [  0   0 140   0   0   0]
#  [  0   0   0 140   0   0]
#  [  0   0   0   0 140   0]
#  [  0   0   0   0   0 140]]
#                  precision    recall  f1-score   support
#
#            ['']       1.00      0.99      0.99       140
# ['আন্তর্জাতিক']       0.99      1.00      1.00       140
#        ['খেলা']       1.00      1.00      1.00       140
#   ['দূর পরবাস']       0.99      1.00      1.00       140
#    ['বাংলাদেশ']       1.00      1.00      1.00       140
#      ['বিনোদন']       1.00      1.00      1.00       140
#
#        accuracy                           1.00       840
#       macro avg       1.00      1.00      1.00       840
#    weighted avg       1.00      1.00      1.00       840
#
#
# Confusion matrix:
#  [[52  1  2  4  0  1]
#  [12 40  1  1  4  2]
#  [ 1  0 59  0  0  0]
#  [ 5  1  1 52  1  0]
#  [10  0  0  6 44  0]
#  [ 6  1  0  6  0 47]]
#                  precision    recall  f1-score   support
#
#            ['']       0.60      0.87      0.71        60
# ['আন্তর্জাতিক']       0.93      0.67      0.78        60
#        ['খেলা']       0.94      0.98      0.96        60
#   ['দূর পরবাস']       0.75      0.87      0.81        60
#    ['বাংলাদেশ']       0.90      0.73      0.81        60
#      ['বিনোদন']       0.94      0.78      0.85        60
#
#        accuracy                           0.82       360
#       macro avg       0.84      0.82      0.82       360
#    weighted avg       0.84      0.82      0.82       360

# %%
#Import model for NB
from sklearn.naive_bayes import GaussianNB,MultinomialNB
from sklearn.metrics import accuracy_score
# create classifier object gor model
model=GaussianNB()

# train the model with fit function
model.fit(trainX, trainY)
   
# make predictions on training data
predictions_train = model.predict(trainX)
print('\nTraining Accuracy using MNB :',accuracy_score(trainY, predictions_train))

# make predictions on test data
predictions_test = model.predict(testX)
print('\nTest Accuracy using MNB :',accuracy_score(testY, predictions_test))


from sklearn.metrics import classification_report, confusion_matrix, accuracy_score
print('\nConfusion matrix:\n',confusion_matrix(trainY,predictions_train))
print(classification_report(trainY,predictions_train))  

print('\nConfusion matrix:\n',confusion_matrix(testY,predictions_test))
print(classification_report(testY,predictions_test))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-70292b52cc18> in <module>
#       6
#       7 # train the model with fit function
# ----> 8 model.fit(trainX, trainY)
#       9
#      10 # make predictions on training data
#
# NameError: name 'trainX' is not defined

# %%
from sklearn.model_selection import cross_validate
from sklearn.model_selection import cross_val_score
from sklearn.metrics import recall_score
#scoring = ['precision_macro', 'recall_macro']

# clf = svm.SVC(kernel='linear', C=1)
scores = cross_val_score(model, dataX, dataY,cv = 5)

# %%
# print(sorted(scores.keys()))
# print(sorted(scores.items()))

print("Accuracy: %0.2f (+/- %0.2f)" % (scores.mean()+ scores.std() * 2,scores.std()* 2))
# Out:
# Accuracy: 0.85 (+/- 0.07)
